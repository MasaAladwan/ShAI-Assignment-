# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # About Features
#
# 1. **Employee ID**: A unique identifier for each employee. Usually a numeric or alphanumeric code.
#
# 2. **Name**: The full name of the employee. This might be split into first and last names in some datasets.
#
# 3. **Department**: The department or division within the organization where the employee works.
#
# 4. **Job Title**: The official title or position held by the employee in the organization.
#
# 5. **Salary**: The amount of money the employee earns. This could be represented as an annual salary, hourly wage, or monthly pay.
#
# 6. **Hire Date**: The date when the employee started working at the organization. Useful for calculating tenure or experience.
#
# 7. **Gender**: The gender of the employee. This might be included in some datasets for diversity and equality analysis.
#
# 8. **Years of Experience**: The total number of years the employee has worked in their field or profession.
#
# 9. **Education Level**: The highest level of education attained by the employee, such as a high school diploma, bachelor's degree, etc.
#
# 10. **Performance Rating**: If available, this could be a measure of the employee's performance in their role, often based on annual review scores.
#
# 11. **Location**: The geographical location or office where the employee works, if the organization has multiple locations.

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt 

# Load your dataset
df = pd.read_csv(r'SalariesX.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency
# 0  2011    NaN  San Francisco
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency'],
#       dtype='object')

# %% [markdown]
# ## Task one

# %% [markdown]
# ### 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.

# %%
print("The number of rows : ",df.shape[0]) 
print("The number of columns : ",df.shape[1])
# Out:
# The number of rows :  148654
# The number of columns :  12

# %%
df.info()  #Data types of each columns + missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148653 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
# dtypes: float64(7), int64(2), object(3)
# memory usage: 13.6+ MB

# %%
df.isnull().sum() # null values in each column
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 1
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# dtype: int64

# %%
df.isnull().sum().sum() # null values in the dataset
# Out:
# 185435

# %% [markdown]
# ## Task two
#  ### Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %% [markdown]
#  ### having salary values with minimum values in the negative range doesnt make sense

# %%
#starting with the BasePay column
df[df["BasePay"]<=0]
# Out:
#             Id      EmployeeName                     JobTitle  BasePay  \
# 2896      2897        JOHN PAYNE                  MANAGER VII      0.0
# 3263      3264  LAWRENCE BADINER                   MANAGER VI      0.0
# 19058    19059     PETER LEONARD       FIRE FIGHTER PARAMEDIC      0.0
# 20834    20835   MICHAEL COLLINS            POLICE OFFICER II      0.0
# 21658    21659   LINDA ZIMMERMAN          PUBLIC HEALTH NURSE      0.0
# ...        ...               ...                          ...      ...
# 148645  148646  Carolyn A Wilson    Human Services Technician      0.0
# 148647  148648    Joann Anderson  Communications Dispatcher 2      0.0
# 148648  148649       Leon Walker                    Custodian      0.0
# 148649  148650     Roy I Tillery                    Custodian      0.0
# 148653  148654         Joe Lopez   Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  \
# ...

# %% [markdown]
# #### Having BasePay <= 0 is not logical so i will set these values to null

# %%
for index, value in enumerate(df["BasePay"]):
    if value <= 0:
        df.at[index, "BasePay"] = np.nan

# %%
df[df["BasePay"]<=0]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency]
# Index: []

# %%
df.BasePay.describe()
# Out:
# count    146736.000000
# mean      66917.130321
# std       42491.578949
# min           6.040000
# 25%       35411.025000
# 50%       65258.010000
# 75%       94984.072500
# max      319275.010000
# Name: BasePay, dtype: float64

# %%
#TotalPay column
for index, value in enumerate(df["TotalPay"]):
    if value <= 0:
        df.at[index, "TotalPay"] = np.nan

# %%
df[df["TotalPay"]<=0]
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency]
# Index: []

# %% [markdown]
# #### Its possible to have benefits, OtherPay, OverTimePay with zero value

# %%
#OtherPay column
for index, value in enumerate(df["OtherPay"]):
    if value < 0:
        df.at[index, "OtherPay"] = np.nan
        
#Benefits 
for index, value in enumerate(df["Benefits"]):
    if value < 0:
        df.at[index, "Benefits"] = np.nan
        
#OvertimePay
for index, value in enumerate(df["OvertimePay"]):
    if value < 0:
        df.at[index, "OvertimePay"] = np.nan

#TotalPay column
for index, value in enumerate(df["TotalPayBenefits"]):
    if value <0:
        df.at[index, "TotalPayBenefits"] = np.nan

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  146736.000000  148649.000000  148645.000000
# mean    74327.500000   66917.130321    5066.093967    3648.942393
# std     42912.857795   42491.578949   11454.411550    8056.664894
# min         1.000000       6.040000       0.000000       0.000000
# 25%     37164.250000   35411.025000       0.000000       0.000000
# 50%     74327.500000   65258.010000       0.000000     811.350000
# 75%    111490.750000   94984.072500    4658.350000    4236.740000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes
# count  112487.000000  148285.000000     148650.000000  148654.000000    0.0
# mean    25008.782944   74954.383468      93695.080429    2012.522643    NaN
# std     15401.766888   50441.766219      62792.490716       1.117538    NaN
# ...

# %%
salary_range = max(df['TotalPay'])- min(df['TotalPay'])
salary_range
# Out:
# 567595.13

# %%
mode_salary = statistics.mode(df.BasePay)
mode_salary
# Out:
# 54703.0

# %%
print("Mean Salary:" ,df.TotalPay.describe().loc["mean"])
print("Median Salary:",df.TotalPay.describe().loc["50%"])
print(f"Mode Salary: {mode_salary}")
print("Minimum Salary:" ,df.TotalPay.describe().loc["min"])
print("Maximum Salary: ",df.TotalPay.describe().loc["max"])
print(f"Salary Range: {salary_range}")
print("Standard Deviation of Salary:",df.TotalPay.describe().loc["std"])
# Out:
# Mean Salary: 74954.38346771421
# Median Salary: 71553.0
# Mode Salary: 54703.0
# Minimum Salary: 0.3
# Maximum Salary:  567595.43
# Salary Range: 567595.13
# Standard Deviation of Salary: 50441.7662188465

# %%
numeric_cols = df.select_dtypes(include='number')  # Select only numeric columns

mode_values = numeric_cols.mode()  # Calculate mode for each numeric column

mode_values = mode_values.drop(columns=['Id']) #drop the id column 

print("Mode of numeric columns:")
for column in mode_values.columns:
    mode = mode_values[column].iloc[0]  # Extract mode value for each column
    if pd.isna(mode):
        print(f"No mode found for column '{column}'")
    else:
        print(f"M"
              f""
              f"ode of column '{column}': {mode}")
# Out:
# Mode of numeric columns:
# Mode of column 'BasePay': 54703.0
# Mode of column 'OvertimePay': 0.0
# Mode of column 'OtherPay': 0.0
# Mode of column 'Benefits': 0.0
# Mode of column 'TotalPay': 18594.0
# Mode of column 'TotalPayBenefits': 7959.18
# Mode of column 'Year': 2014.0
# No mode found for column 'Notes'

# %%
display(df[df["JobTitle"]==("Junior Clerk")])
# Out:
#             Id          EmployeeName      JobTitle   BasePay  OvertimePay  \
# 61820    61821          Eddy Redondo  Junior Clerk  45263.51         0.00
# 61839    61840          Enrico Intal  Junior Clerk  45263.50         0.00
# 62611    62612  Sonia Coronado-Brown  Junior Clerk  36531.24      4071.76
# 62657    62658         Milton Martin  Junior Clerk  39909.50         0.00
# 63145    63146      Vladimir Vallejo  Junior Clerk  38201.57         0.00
# ...        ...                   ...           ...       ...          ...
# 148285  148286         Greg K Hansen  Junior Clerk    156.50       249.42
# 148300  148301         Julien N Heng  Junior Clerk    152.00       228.00
# 148307  148308    Fernando Rodriguez  Junior Clerk    371.69         0.00
# 148386  148387         Michael Brito  Junior Clerk    156.50       102.70
# 148586  148587       Kesha Mcwhorter  Junior Clerk     48.91         0.00
#
#         OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# ...

# %% [markdown]
# #### by observing employees with the same jobTitle and Agency have variance in salaries,its  might not make logical sense , need more info about the data like : Experience Level, Negotiation, Market Conditions , nternal Pay Equity Issues, Seniority....

# %% [markdown]
# ## Task three
# ### Handle missing data by suitable method with explain why you use it.

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 1
# BasePay               1918
# OvertimePay              5
# OtherPay                 9
# Benefits             36167
# TotalPay               369
# TotalPayBenefits         4
# Year                     0
# Notes               148654
# Agency                   0
# dtype: int64

# %%
df = df.drop(columns=["Notes"])

# %%
not_null_rows = df[df.notnull().all(axis=1)]
not_null_rows
# Out:
#             Id            EmployeeName                      JobTitle  \
# 36159    36160          Gary Altenberg  Lieutenant, Fire Suppression
# 36160    36161            Gregory Suhr               Chief of Police
# 36161    36162              Khoa Trinh   Electronic Maintenance Tech
# 36162    36163      Joanne Hayes-White        Chief, Fire Department
# 36163    36164       Frederick Binkley     EMT/Paramedic/Firefighter
# ...        ...                     ...                           ...
# 148613  148614         Nanette M Lloyd                 Special Nurse
# 148616  148617       Afakasi O Afakasi        Public Service Trainee
# 148617  148618  Charles F Williams Iii                Pool Lifeguard
# 148619  148620           Ian V Cameron  IS Program Analyst-Assistant
# 148620  148621         India C Sabater             Recreation Leader
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# 36159   128808.87    220909.48  13126.31  44430.12  362844.66
# ...

# %% [markdown]
# #### by obsearving the data , i notice that the TotalPay = BasePay+OvertimePay+OtherPay  and  TotalPayBenefits = TotalPay +Benefits   for that i will set the TotalPay and TotalPayBenefits

# %%
df["TotalPay"] = 0 
df["TotalPayBenefits"] = 0

# %%
unique_job_titles_count = df['JobTitle'].nunique()
print("Number of unique job titles:", unique_job_titles_count)
# Out:
# Number of unique job titles: 2159

# %%
df.JobTitle.unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], dtype=object)

# %% [markdown]
# #### The JobTitles need preprocessing , and there is missing info .
# #### 1. Is "COMMUNICATIONS DISPATCHER I" same as "COMMUNICATIONS DISPATCHER II"?
# #### 2. Is "ADMINISTRATIVE ANALYST" same as "ADMINISTRATIVE ANALYST II " as "ADMINISTRATIVE ANALYST III" ? ......
# #### there are alot of titles like this , i will leave it as it is , since i dont have enough info
#
# #### 3. "X-Ray Laboratory Aide" is te same as "X-Ray Laboratory AIDE" , i will make all JobTitle UpperCase

# %%
# make all Jobtite UpperCase 
df['JobTitle'] = df['JobTitle'].str.upper()

# %%
df.JobTitle.nunique()
# Out:
# 1637

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       CUSTODIAN        NaN
# ...

# %% [markdown]
# ### fill the null values of salary  by the JobTitle , hence groupby job title and calculate the mean

# %%
""""# Group by 'JobTitle' and calculate the mean BasePay for each job title
mean_BasePay_by_job_title = df.groupby('JobTitle')['BasePay'].mean()

# Group by 'JobTitle' and calculate the mean Benefits for each job title
mean_Benefits_by_job_title = df.groupby('JobTitle')['Benefits'].mean()

print("Mean Benefits by JobTitle:",mean_Benefits_by_job_title)
print("Mean BasePay by JobTitle:",mean_BasePay_by_job_title)

"""
# Out:
# '"# Group by \'JobTitle\' and calculate the mean BasePay for each job title\nmean_BasePay_by_job_title = df.groupby(\'JobTitle\')[\'BasePay\'].mean()\n\n# Group by \'JobTitle\' and calculate the mean Benefits for each job title\nmean_Benefits_by_job_title = df.groupby(\'JobTitle\')[\'Benefits\'].mean()\n\nprint("Mean Benefits by JobTitle:",mean_Benefits_by_job_title)\nprint("Mean BasePay by JobTitle:",mean_BasePay_by_job_title)\n\n'

# %%
"""" # didnt work 
# Iterate over each job title group and fill missing values with the mean Benefits  for that job title
for job_title, mean_Benefits in mean_Benefits_by_job_title.items():
    df.loc[df['JobTitle'] == job_title, 'Benefits'].fillna(mean_Benefits, inplace=True)

# Iterate over each job title group and fill missing values with the mean BasePay  for that job title
for job_title, mean_BasePay in mean_Benefits_by_job_title.items():
    df.loc[df['JobTitle'] == job_title, 'BasePay'].fillna(mean_BasePay, inplace=True)
    
#df['Benefits'] = df['Benefits'].fillna(df.groupby('JobTitle')['Benefits'].transform('mean'))
"""
# Out:
# '" # didnt work \n# Iterate over each job title group and fill missing values with the mean Benefits  for that job title\nfor job_title, mean_Benefits in mean_Benefits_by_job_title.items():\n    df.loc[df[\'JobTitle\'] == job_title, \'Benefits\'].fillna(mean_Benefits, inplace=True)\n\n# Iterate over each job title group and fill missing values with the mean BasePay  for that job title\nfor job_title, mean_BasePay in mean_Benefits_by_job_title.items():\n    df.loc[df[\'JobTitle\'] == job_title, \'BasePay\'].fillna(mean_BasePay, inplace=True)\n    \n#df[\'Benefits\'] = df[\'Benefits\'].fillna(df.groupby(\'JobTitle\')[\'Benefits\'].transform(\'mean\'))\n'

# %%
# Fill missing values in 'BasePay' and 'Benefits' columns with the mean values for the entire dataset
df['BasePay'].fillna(df['BasePay'].mean(), inplace=True)
df['Benefits'].fillna(df['Benefits'].mean(), inplace=True)

# Group by 'JobTitle' and fill missing values with the means of 'BasePay' and 'Benefits' for each group
df[['BasePay', 'Benefits']] = df.groupby('JobTitle')[['BasePay', 'Benefits']].transform(lambda x: x.fillna(x.mean()))

# Now, all missing values in 'BasePay' and 'Benefits' columns should be filled with the mean values for each job title

# %%
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            1
# BasePay             1
# OvertimePay         5
# OtherPay            9
# Benefits            1
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#             Id       EmployeeName                       JobTitle  \
# 84969    84970          Pei  Meng  IS BUSINESS ANALYST-PRINCIPAL
# 90714    90715  Claudia M Sanchez      SENIOR ELIGIBILITY WORKER
# 93200    93201       Jose A Lemus           CUSTODIAL SUPERVISOR
# 94755    94756  Robert E Gonzales                            NaN
# 96168    96169   John G Alexander                       GARDENER
# 107184  107185   Amelie E Bullard                  SPECIAL NURSE
# 148646  148647       Not provided                   NOT PROVIDED
# 148650  148651       Not provided                   NOT PROVIDED
# 148651  148652       Not provided                   NOT PROVIDED
# 148652  148653       Not provided                   NOT PROVIDED
# 148653  148654          Joe Lopez     COUNSELOR, LOG CABIN RANCH
#
#               BasePay  OvertimePay  OtherPay      Benefits  TotalPay  \
# 84969   101274.510000         0.00       NaN  34583.400000         0
# ...

# %%
df.dropna()
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148644  148645       Randy D Winn
# 148645  148646   Carolyn A Wilson
# 148647  148648     Joann Anderson
# 148648  148649        Leon Walker
# 148649  148650      Roy I Tillery
#
#                                               JobTitle        BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.180000
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.020000
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.130000
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.000000
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.600000
# ...                                                ...            ...
# ...

# %%
df['TotalPay'] = df['BasePay'] + df['OtherPay'] + df['OvertimePay']
df["TotalPayBenefits"] = df["TotalPay"]+ df["Benefits"]

# %% [markdown]
# ## Task 4
# ### Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.

# %%
# Create a pie chart to represent the proportion of employees in different departments
department_counts = df['JobTitle'].value_counts().head(10)  # Assuming you want to visualize the top 10 departments
plt.figure(figsize=(8, 8))
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Employees in Different Departments')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
import seaborn as sns

# Top N Job Titles
top_n = 20  # Change this value as needed

top_job_titles = df['JobTitle'].value_counts().head(top_n)

plt.figure(figsize=(10, 6))
top_job_titles.plot(kind='barh')
plt.title(f'Top {top_n} Most Common Job Titles')
plt.xlabel('Frequency')
plt.ylabel('Job Title')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest frequency at the top
plt.show()

# %%
# Create a histogram to visualize the distribution of salaries
plt.figure(figsize=(10, 6))
plt.hist(df['TotalPay'], bins=30, color='skyblue', edgecolor='black')
plt.title('Distribution of Salaries')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot for TotalPay by Year
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Year', y='TotalPay')
plt.title('Total Pay by Year')
plt.xlabel('Year')
plt.ylabel('Total Pay')
plt.show()

# %% [markdown]
# ## Task 5
# ### **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.

# %%
current_year = pd.Timestamp.now().year

# Calculate the years of experience based on the 'Year' column
df['YearsOfExperience'] = current_year - df['Year']

# %%
# Group the data by one or more columns 
grouped_data = df.groupby(['JobTitle', 'YearsOfExperience'])

# Calculate summary statistics for each group
summary_statistics = grouped_data.agg({'TotalPay': 'mean'})

# Compare the average salaries across different groups
print(summary_statistics)
# Out:
#                                                                       TotalPay
# JobTitle                                       YearsOfExperience
# ACCOUNT CLERK                                  10                 39839.850333
#                                                11                 46911.814455
#                                                12                 46066.717765
#                                                13                 44035.664337
# ACCOUNTANT                                     13                 60812.694064
# ...                                                                        ...
# YOUTH COMM ADVISOR                             10                 36465.910000
#                                                11                 35823.295000
#                                                12                 57544.730000
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS 13                 53632.870000
# ...

# %% [markdown]
# ## Task 6
# ### Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.

# %%
cm = df.corr()
sns.heatmap(cm)
# Out:
# /var/folders/v8/l1_1hkns6bzgr_mh923vgcbh0000gn/T/ipykernel_2325/3046827348.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cm = df.corr()
# <Axes: >

# %%
dfs = df.select_dtypes(include='number') 
dfs = dfs.drop(columns="Id")# Select only numeric columns
scatter_matrix = pd.plotting.scatter_matrix(dfs)
# Adjust rotation of y-axis labels
"""for ax in scatter_matrix.ravel():
    ax.set_ylabel(ax.get_ylabel(), rotation=0, fontsize=8, horizontalalignment='right')
    ax.set_xlabel(ax.get_xlabel(), rotation=90, fontsize=8, horizontalalignment='center')"""

plt.show()

# %%
dfs.corr()
# Out:
#                     BasePay  OvertimePay  OtherPay  Benefits  TotalPay  \
# BasePay            1.000000     0.263549  0.288271  0.799182  0.953494
# OvertimePay        0.263549     1.000000  0.316586  0.268530  0.503856
# OtherPay           0.288271     0.316586  1.000000  0.203626  0.478224
# Benefits           0.799182     0.268530  0.203626  1.000000  0.770996
# TotalPay           0.953494     0.503856  0.478224  0.770996  1.000000
# TotalPayBenefits   0.958173     0.472445  0.437122  0.852725  0.990107
# Year               0.031419     0.027888 -0.002487 -0.027384  0.032601
# YearsOfExperience -0.031419    -0.027888  0.002487  0.027384 -0.032601
#
#                    TotalPayBenefits      Year  YearsOfExperience
# BasePay                    0.958173  0.031419          -0.031419
# OvertimePay                0.472445  0.027888          -0.027888
# OtherPay                   0.437122 -0.002487           0.002487
# Benefits                   0.852725 -0.027384           0.027384
# ...

# %%
correlation = df['TotalPay'].corr(df['BasePay'])

# Print the correlation coefficient
print("Correlation coefficient between 'TotalPay' and 'BasePay':", correlation)

# Plot a scatter plot to visualize the relationship between 'TotalPay' and 'BasePay'
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='BasePay', y='TotalPay', color='blue', alpha=0.5)
plt.title('Scatter Plot: TotalPay vs BasePay')
plt.xlabel('BasePay')
plt.ylabel('TotalPay')
plt.grid(True)
plt.show()
# Out:
# Correlation coefficient between 'TotalPay' and 'BasePay': 0.9534943318382063

# %% [markdown]
# ## Task 7
#
# **Summary of Insights**
#
# Through the process of this assignment, several observations and actions were made to preprocess and analyze the dataset. Here are the key findings and insights:
#
# 1. **Data Preprocessing**:
#    - Noticed that having salary values in the negative range and BasePay values less than or equal to zero were illogical, so these values were set to null.
#    - The Notes column contained a large number of missing values (148,654), so it was dropped from the dataset.
#    - TotalPay and TotalPayBenefits were calculated based on BasePay, OvertimePay, and OtherPay. However, as these columns contained wrong values, they were set to zero initially and recalculated later.
#    - JobTitle required preprocessing, such as converting all titles to uppercase to standardize them. The number of unique job titles was reduced from 2159 to 1637.
#
# 2. **Grouped Analysis**:
#    - The data was grouped by JobTitle, and missing values in BasePay and Benefits were filled with the means of each group.
#
# 3. **Visualization**:
#    - A pie chart was used to represent the proportion of employees in different departments.
#    - A horizontal bar plot was created to visualize the top 20 most common job titles.
#    - A histogram displayed the distribution of salaries.
#    - A box plot was utilized to identify outliers in TotalPay by Year.
#    - A scatter plot was employed to visualize the relationship between TotalPay and BasePay.
#
# 4. **New Column**:
#    - A new column, YearsOfExperience, was added to the dataset, representing the years of experience of each employee.
#
# 5. **Correlation Analysis**:
#    - The pd.plotting.scatter_matrix function was used to identify any correlation between columns. Column names in both the x-axis and y-axis were adjusted for convenience.
#
# 6. **Detailed Correlation Analysis**:
#    - A heatmap and the corr() function were utilized for a more detailed understanding of the correlation between variables.
#
# Overall, these analyses provided insights into the dataset, highlighting potential areas for further investigation, such as understanding the variance in salaries among employees with the same job title and agency and exploring the relationships between different variables. Further analysis could involve exploring the impact of experience level, negotiation, market conditions, and other factors on salary discrepancies.
